# %% [markdown]
# # Compare Explanation

# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
from datetime import date

import matplotlib.pyplot as plt
from sktime.classification.shapelet_based import MrSEQLClassifier
from sklearn.linear_model import RidgeClassifierCV
from pyts.transformation import WEASEL
from sklearn.metrics import accuracy_score

from scripts.Noise import Noise
from scripts.Explanation import GetExplanation, reshape_lime_explanation, load_explanation, create_random_explanation
import utils.visualization as vis
from utils.data import LocalDataLoader, data_summary
from scripts.Experiment import Evaluate
from scripts.CompareExplanation import CompareExplanation, run_experiment, get_final_ranking, summarize_auc

# %load_ext autoreload
# %autoreload 2

# %%
# ds_list = [ 'ECG5000',
#     'CMJ',
#     'CBF',
#     'ECG200',
#            'Coffee', 'GunPoint'
#           ]
# ds_list = ['SmallMiddle_CAR',  'RareTime_NARMA']
ds_list = [
#     'CBF',
#            'GunPoint','Coffee',
#     'ECG200',
#     'GunPoint','TwoPatterns','GunPointOldVersusYoung'
#     'ItalyPowerDemand',
#     'GunPointAgeSpan',
#     'CMJ'
#     'TwoLeadECG','ECGFiveDays','UWaveGestureLibraryZ',
#     'GunPointMaleVersusFemale',
#     'WormsTwoClass','TwoPatterns','CinCECGTorso','ECG5000',
#     'PowerCons','Wafer','Trace','SonyAIBORobotSurface1','SonyAIBORobotSurface2','Plane',
#     'CricketX','Haptics',  'CBF', 'Coffee', 'ECG200',
#     'ECG5000',
#     'Meat','Strawberry',
#     'WormsTwoClass'
# 'SmallMiddle_CAR','RareTime_NARMA',
#            'Moving_RareTime_CAR', 'Moving_RareTime_PseudoPeriodic', 'Moving_RareTime_Harmonic', 'PostionalFeature_Harmonic','PostionalFeature_PseudoPeriodic'
          ]
ds_dir = 'data'

for ds in ds_list:
    print(ds)
    data_summary(ds_dir,ds)
    print('------------------------------')
# Out:
# PowerCons
# Dataset: PowerCons
# X_train.shape:  (180, 1, 144)
# X_test.shape:  (180, 1, 144)
# Unique target class:  ['0', '1']
# Dataset: PowerCons, Training Data-Global mean value: 1.10247
# ------------------------------
# Wafer
# Dataset: Wafer
# X_train.shape:  (1000, 1, 152)
# X_test.shape:  (6164, 1, 152)
# Unique target class:  ['0', '1']
# Dataset: Wafer, Training Data-Global mean value: -0.00000
# ------------------------------
# Trace
# Dataset: Trace
# X_train.shape:  (100, 1, 275)
# X_test.shape:  (100, 1, 275)
# Unique target class:  ['0', '1', '2', '3']
# Dataset: Trace, Training Data-Global mean value: 0.00000
# ------------------------------
# SonyAIBORobotSurface1
# Dataset: SonyAIBORobotSurface1
# X_train.shape:  (20, 1, 70)
# X_test.shape:  (601, 1, 70)
# Unique target class:  ['0', '1']
# Dataset: SonyAIBORobotSurface1, Training Data-Global mean value: -0.00000
# ------------------------------
# SonyAIBORobotSurface2
# Dataset: SonyAIBORobotSurface2
# X_train.shape:  (27, 1, 65)
# X_test.shape:  (953, 1, 65)
# Unique target class:  ['0', '1']
# Dataset: SonyAIBORobotSurface2, Training Data-Global mean value: 0.00000
# ------------------------------
# Plane
# Dataset: Plane
# X_train.shape:  (105, 1, 144)
# X_test.shape:  (105, 1, 144)
# Unique target class:  ['0', '1', '2', '3', '4', '5', '6']
# Dataset: Plane, Training Data-Global mean value: -0.00000
# ------------------------------

# %% [raw]
# # MRSEQL accuracy
#
# model = MrSEQLClassifier(seql_mode="fs")
# model.fit(X_train,y_train)
# preds = model.predict(X_test)
#
# print('MrSEQL Accuracy on %s dataset: ' %ds, accuracy_score(y_test,preds))

# %% [markdown]
# ### Compare

# %%
ds_list = ['TwoPatterns']

xais = ['LIME', 'MrSEQL','GradientShap','IG','ROCKET','RIDGECV','ROCKET_SHAP']
explanation_names = ['lime_mrseql', 'mrseql','GS','IG','lime_rocket','ridgecv','rocket-shap'] 

ref_list = ['rocket','resnet','knn','MrSEQLClassifier']
for ds in ds_list:
    print(ds)
    run_experiment(datapath=ds_dir,dataset=ds,
                   xais = xais, explanation_names = explanation_names,
                   referee_list=ref_list, 
                   perturbation_types=[
        'local_mean','global_mean',
        'global_gaussian','local_gaussian'
    ],
                include_random_exp=False, evaluation_on_subset=False, eval_size=0.05)
# Out:
# TwoPatterns
# Explanation Shape:  (4000, 128)
# Total numbers of XAI Methods:  1
# Names of XAI Methods:  ['ridgecv']
# Referees:  ['rocket', 'resnet', 'knn', 'MrSEQLClassifier']
# C:\Users\trang\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:145: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), _RidgeGCV())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# C:\Users\trang\Google Drive\github\explanation4tsc-2nd\scripts\Experiment.py:134: FutureWarning: Call to deprecated class MrSEQLClassifier. (MrSEQLClassifier will be removed in v0.10.0. It will be replaced with an implementation based on Numba.) -- Deprecated since version 0.8.1.
#   model = MrSEQLClassifier(seql_mode="fs")
# C:\Users\trang\Google Drive\github\explanation4tsc-2nd\scripts\Experiment.py:134: FutureWarning: Call to deprecated class SEQLCLF. (SEQLCLF will be removed in v0.10.0) -- Deprecated since version 0.8.1.
#   model = MrSEQLClassifier(seql_mode="fs")

# %%
ds_list = [ 
    'CMJ',
# ?    'CBF',
    'ECG200',
           'Coffee', 'GunPoint'
          ]

ref_list = ['weasel']
for ds in ds_list:

    run_experiment(datapath=ds_dir,dataset=ds,referee_list=ref_list, perturbation_types=[
        'local_mean','global_mean',
        'global_gaussian','local_gaussian'
    ],
                include_random_exp=True, evaluation_on_subset=False  )
# Out:
# (179, 10)
# (179, 1, 500)
# (179, 10)
# (179, 1, 500)
# Explanation Shape:  (179, 500)
# Total numbers of XAI Methods:  7
# Names of XAI Methods:  ['lime_mrseql', 'mrseql', 'cam', 'GS', 'IG', 'lime_rocket', 'random2020']
# (100, 10)
# (100, 1, 96)
# (100, 10)
# (100, 1, 96)
# Explanation Shape:  (100, 96)
# Total numbers of XAI Methods:  7
# Names of XAI Methods:  ['lime_mrseql', 'mrseql', 'cam', 'GS', 'IG', 'lime_rocket', 'random2020']
# (28, 10)
# (28, 1, 286)
# (28, 10)
# (28, 1, 286)
# Explanation Shape:  (28, 286)
# Total numbers of XAI Methods:  7
# Names of XAI Methods:  ['lime_mrseql', 'mrseql', 'cam', 'GS', 'IG', 'lime_rocket', 'random2020']
# (150, 10)
# (150, 1, 150)
# (150, 10)
# (150, 1, 150)
# Explanation Shape:  (150, 150)
# Total numbers of XAI Methods:  7
# Names of XAI Methods:  ['lime_mrseql', 'mrseql', 'cam', 'GS', 'IG', 'lime_rocket', 'random2020']

# %%
weight = np.genfromtxt('exp_weights/weights_ROCKET_SHAP_CMJ.txt', delimiter = ',')

# %%
weight.shape
# Out:
# (179, 10)

# %%
explanation = np.repeat(weight, 286//10).reshape(12,-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-559a73d9d8b2> in <module>
# ----> 1 explanation = np.repeat(weight, 286//10).reshape(12,-1)
#
# ValueError: cannot reshape array of size 7840 into shape (12,newaxis)

# %%
xais = ['ROCKET_SHAP']
names = ['rocket-shap']

# if ds in ['CBF', 'CMJ', 'Coffee', 'ECG200', 'GunPoint']:
#     xais = ['LIME', 'MrSEQL', 'Resnet','GradientShap','IG'] 
#     names =[ 'lime_mrseql', 'mrseql', 'cam','GS','IG']
# else:
#     xais = ['LIME', 'MrSEQL','GradientShap','IG'] 
#     names =[ 'lime_mrseql', 'mrseql','GS','IG']

referees = ['rocket','resnet','knn','MrSEQLClassifier',]
noise_types = ['global_mean','local_mean']


########### Dont change here ############
assert len(xais) == len(names)
random_seeds = [2020]
lime_xais = ['lime','LIME','Lime']
today = str(date.today()).replace('-', '')
# xais = ['LIME', 'MrSEQL', 'Resnet','GradientShap','IG'] 
# names =[ 'lime_mrseql', 'mrseql', 'cam','GS','IG']
# referees = ['knn', 'MrSEQLClassifier','rocket',] # resnet, weasel, rocket -- just need estimators?

# %%
# Load weights
weights = []
for xai in xais:
    is_reshape=True if xai in lime_xais else False
    weight = load_explanation(datapath=ds_dir,dataset=ds,explanation_type=xai,reshape_lime=is_reshape)
    weights.append(weight)

# for seed in random_seeds:
#     random_weight, random_weight_name = create_random_explanation(datapath=ds_dir,dataset=ds)
#     weights.append(random_weight)
#     names.append(random_weight_name)


print('Explanation Shape: ', weights[0].shape)
print('Total numbers of XAI Methods: ', len(weights))
print('Names of XAI Methods: ', names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2ec8c3f24b1c> in <module>
#       1 # Load weights
#       2 weights = []
# ----> 3 for xai in xais:
#       4     is_reshape=True if xai in lime_xais else False
#       5     weight = load_explanation(datapath=ds_dir,dataset=ds,explanation_type=xai,reshape_lime=is_reshape)
#
# NameError: name 'xais' is not defined

# %%
weights[0][0]
# Out:
# array([ 0.00981444,  0.0092265 ,  0.01255605,  0.00019696, -0.00079272,
#        -0.02395746,  0.00384999,  0.02820625, -0.17481562, -0.04182292])

# %%
for ds in ds_list:

    run_experiment(datapath=ds_dir,dataset=ds, perturbation_types=[
        'local_mean','global_mean',
        'global_gaussian','local_gaussian'
    ])
# Out:
# Explanation Shape:  (186, 128)
# Total numbers of XAI Methods:  7
# Names of XAI Methods:  ['lime_mrseql', 'mrseql', 'GS', 'IG', 'lime_rocket', 'ridgecv', 'random2020']
# C:\Users\trang\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:145: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), _RidgeGCV())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,

# %%
data = LocalDataLoader(datapath=ds_dir,dataset=ds)
X_train,y_train,X_test,y_test =data.get_X_y(onehot_label=False)
exp = weights[0]
for i in range(len(X_test)+1):
    if i<50:
        print('Index %d ; True Class %d' %(i,y_test[i]))
        vis.visualize_explanation(i,X_test,exp,ds=ds, savefig=False)
# Out:
# Index 0 ; True Class 0
# Index 1 ; True Class 0
# Index 2 ; True Class 0
# Index 3 ; True Class 0
# Index 4 ; True Class 0
# Index 5 ; True Class 0
# Index 6 ; True Class 0
# Index 7 ; True Class 0
# Index 8 ; True Class 0
# Index 9 ; True Class 0
# Index 10 ; True Class 0
# Index 11 ; True Class 0
# Index 12 ; True Class 0
# Index 13 ; True Class 0
# Index 14 ; True Class 0
# Index 15 ; True Class 0
# Index 16 ; True Class 0
# Index 17 ; True Class 0
# Index 18 ; True Class 0
# Index 19 ; True Class 0
# Index 20 ; True Class 0
# Index 21 ; True Class 0
# Index 22 ; True Class 0
# Index 23 ; True Class 0
# Index 24 ; True Class 0
# Index 25 ; True Class 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0df06c28fd13> in <module>
#       5     if i<50:
#       6         print('Index %d ; True Class %d' %(i,y_test[i]))
# ----> 7         vis.visualize_explanation(i,X_test,exp,ds=ds, savefig=False)
#
# ~\Google Drive\github\explanation4tsc-2nd\utils\visualization.py in visualize_explanation(idx, X_series, explanation, ds, savefig)
#      67     if savefig:
#      68         plt.savefig('temp.pdf',format='pdf',dpi=300)
# ---> 69     else: plt.show()
#      70
#      71
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~\AppData\Roaming\Python\Python37\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\AppData\Roaming\Python\Python37\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\AppData\Roaming\Python\Python37\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <C:\Users\trang\AppData\Roaming\Python\Python37\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~\AppData\Roaming\Python\Python37\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\AppData\Roaming\Python\Python37\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\AppData\Roaming\Python\Python37\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\AppData\Roaming\Python\Python37\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     881     def draw(self, renderer):
#     882         self.set_sizes(self._sizes, self.figure.dpi)
# --> 883         Collection.draw(self, renderer)
#     884
#     885
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py in draw(self, renderer)
#     330                 self._linewidths, self._linestyles,
#     331                 self._antialiaseds, self._urls,
# --> 332                 self._offset_position)
#     333
#     334         gc.restore()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\path.py in vertices(self)
#     201         self._has_nonfinite = not np.isfinite(self._vertices).all()
#     202
# --> 203     @property
#     204     def vertices(self):
#     205         """
#
# KeyboardInterrupt:

# %%
data = LocalDataLoader(datapath=ds_dir,dataset=ds)
X_train,y_train,X_test,y_test =data.get_X_y(onehot_label=False)
exp = weights[0]
for i in range(len(X_test)+1):
    if i == 10:
        print('Index %d ; True Class %d' %(i,y_test[i]))
        vis.visualize_explanation(i,X_test,exp,ds=ds,savefig=True)
# Out:
# Index 10 ; True Class 0

# %%
plt.show()

# %% [markdown]
# ## Visualize from saved results

# %%
for ds in ds_list:
#     path = './output/acc_%s_%s.csv' %(ds,'20220808')
    
    path = glob.glob('./output/acc_%s_*.csv'%(ds))
    acc_df = pd.read_csv(path)
    for noise_type in ['global_mean','local_mean']:
        df1 = acc_df.loc[acc_df['noise_type'] == noise_type]
        path = './plot/acc_curve_%s_%s' %(ds,noise_type)
        vis.visualize_experiment_result(df1,savefig=False, savepath=path)

# %%
df = pd.read_csv('filtered.csv')
ds_list = df['dataset'].tolist()
# col_names = df.columns.values.tolist()
# col_names = col_names.append(['best_method', 'worst_method'])
best, worst = [],[]

for ds in ds_list:
    if ds not in ['Car','Wafer']:
        print(ds)
        path = glob.glob('./output/%s_*.csv'%(ds))
        if not path:
            print('No comparison result exists')
            print('---')

        else:
            path = path[0]
            auc_df =pd.read_csv(path)
        #     summarize_auc(auc_df)
            x = get_final_ranking(auc_df,beautify_display=False)
            curr_best = x['XAI_method'][x['scaled_ranking'].idxmin()] 
            curr_worst = x['XAI_method'][x['scaled_ranking'].idxmax()] 
            print('Best method: ', curr_best)
            print('Worst method: ', curr_worst)
            print('---')

# %%
ds_list =  ['Ham']
for ds in ds_list:
    path = glob.glob('./output/%s_*.csv'%(ds))[0]
    auc_df =pd.read_csv(path)
    summarize_auc(auc_df)
    get_final_ranking(auc_df)

# %%
threshold = 20
noise = Noise(X=X_test,explanation=exp, noise_type='global_gaussian')

noise.add_noise(threshold=threshold)
X_perturbed = noise.X_perturbed_3d 
print(X_perturbed.shape)
noise.visualize(idx =70,threshold=threshold,dataset_name=ds)
# Out:
# (179, 1, 500)

# %%
from scripts.Noise import Noise
