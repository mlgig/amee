# %%
import pandas as pd
import glob
from os import listdir
import seaborn as sns
from os.path import isfile, join
from scripts.CompareExplanation import get_final_ranking, summarize_auc, get_final_ranking_new
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Synthetic Dataset

# %%
ds_list = [
    'SmallMiddle_CAR','RareTime_NARMA',
#     'CMJ','ECG200','CBF','Coffee',
]

colnames = ['dataset', 'best','worst']
df = pd.DataFrame(columns=colnames)

for ds in ds_list:
    if ds not in ['Beef','Ham','OliveOil','Wine']:
        print(ds)
        path = glob.glob('./output/%s_*.csv'%(ds))
#         print(path)
        if not path:
            print('No comparison result exists')
            print('---')
        if len(path)>3: 
            print('More than 3 df found')
        else:
#             path = path[0]
            data1 =pd.read_csv(path[0])
            data2=pd.read_csv(path[1])
            data3=pd.read_csv(path[2])
            auc_df=pd.concat([data1,data2,data3], ignore_index=True, axis=0)
#             auc_df =pd.read_csv(path)
#             summarize_auc(auc_df)
            x1 = get_final_ranking_new(auc_df,beautify_display=True,ranking_by_perturbation_method=False)
            x2 = get_final_ranking_new(auc_df,beautify_display=True,ranking_by_perturbation_method=True)


# x['average_scaled_auc']
# Out:
# SmallMiddle_CAR
# <style  type="text/css" >
# #T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row0_col2,#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row0_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row1_col2,#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row1_col3{
#             background-color:  #048204;
#             color:  #f1f1f1;
#         }#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row2_col2,#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row2_col3{
#             background-color:  #5eb45e;
#             color:  #000000;
#         }#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row3_col2,#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row3_col3{
#             background-color:  #2e992e;
#             color:  #000000;
#         }#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row4_col2,#T_1dc7c530_2f79_11ed_80b0_84fdd18a2cb1row4_col3{
#             background-color:  #8dce8d;
#             color:  #000000;
# ...

# %% [markdown]
# ### UCR dataset

# %%
ds_list = [
#     'SmallMiddle_CAR','RareTime_NARMA',
    'CMJ','ECG200','GunPoint','Coffee',
]

colnames = ['dataset', 'best','worst']
df = pd.DataFrame(columns=colnames)

for ds in ds_list:
    if ds not in ['Beef','Ham','OliveOil','Wine']:
        print(ds)
        path = glob.glob('./output/%s_*.csv'%(ds))
#         print(path)
        if not path:
            print('No comparison result exists')
            print('---')
        if len(path)>3: 
            print('More than 3 df found')
        else:
#             path = path[0]
            data1 =pd.read_csv(path[0])
            data2=pd.read_csv(path[1])
            data3=pd.read_csv(path[2])
            auc_df=pd.concat([data1,data2,data3], ignore_index=True, axis=0)
#             auc_df =pd.read_csv(path)
#             summarize_auc(auc_df)
            x1 = get_final_ranking_new(auc_df,beautify_display=True,ranking_by_perturbation_method=False)
            x2 = get_final_ranking_new(auc_df,beautify_display=True,ranking_by_perturbation_method=True)


# x['average_scaled_auc']
# Out:
# CMJ
# <style  type="text/css" >
# #T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row0_col2,#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row0_col3{
#             background-color:  #cef2ce;
#             color:  #000000;
#         }#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row1_col2,#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row1_col3{
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row2_col2,#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row2_col3{
#             background-color:  #b1e2b1;
#             color:  #000000;
#         }#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row3_col2,#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row3_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row4_col2,#T_4ae4ad12_2f79_11ed_88cc_84fdd18a2cb1row4_col3{
#             background-color:  #7cc57c;
#             color:  #000000;
# ...
